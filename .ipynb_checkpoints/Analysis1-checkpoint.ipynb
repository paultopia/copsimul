# %%
import pandas as pd
import numpy as np
import matplotlib  
# %matplotlib inline
import matplotlib.pyplot as plt
import statsmodels
import plottyprint

# %%
df = pd.read_json("sorted_simul_dump.json")

# %%
df.head()
# Out:
#    bias  inequality  segregation
# 0   0.0    1.021505           13
# 1   0.1    1.215909           13
# 2   0.2    1.407256           13
# 3   0.3    1.729814           13
# 4   0.4    1.852556           13

# %%
import seaborn as sns

# %%
sns.distplot(df['segregation'])

# %%
sns.distplot(df['inequality'])

# %%
sns.regplot(df["inequality"], df["segregation"])

# %%
from mpl_toolkits import mplot3d

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(df["segregation"], df["bias"], df["inequality"])

# %%
df.groupby('bias')['inequality'].mean()
# Out:
# bias
# 0.0    1.000646
# 0.1    1.208446
# 0.2    1.418168
# 0.3    1.628886
# 0.4    1.837113
# Name: inequality, dtype: float64

# %%
import statsmodels.api as sm

# %%
df.groupby('segregation')['inequality'].mean()
# Out:
# segregation
# 0     1.403754
# 2     1.403116
# 3     1.405892
# 4     1.407464
# 5     1.408614
# 6     1.416122
# 7     1.419680
# 8     1.426125
# 9     1.431299
# 10    1.438470
# 11    1.448207
# 12    1.458083
# 13    1.468593
# 14    1.473405
# 15    1.466461
# 16    1.498787
# Name: inequality, dtype: float64

# %%
df['inequality'].mean()
# Out:
# 1.4186518405648445

# %%
lm = sm.OLS(df['inequality'], sm.add_constant(df[['segregation', 'bias']])).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             inequality   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.971
# Method:                 Least Squares   F-statistic:                 4.217e+05
# Date:                Tue, 24 Jul 2018   Prob (F-statistic):               0.00
# Time:                        18:15:54   Log-Likelihood:                 38912.
# No. Observations:               25000   AIC:                        -7.782e+04
# Df Residuals:                   24997   BIC:                        -7.779e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const           0.9674      0.001   1037.157      0.000         0.966     0.969
# ...

# %%
# let's get a printable plot for the chapter
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df["segregation"], df["bias"], df["inequality"], c='black', marker='o')
ax.locator_params(nbins=4)
ax.set_xlabel('Segregation')
ax.set_ylabel('Bias Level')
ax.set_zlabel('Inequality', rotation="horizontal")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color((0.1, 0.1, 0.1, 0.2))
ax.spines['bottom'].set_color((0.1, 0.1, 0.1, 0.2))

# %%
# need to work on this more later
